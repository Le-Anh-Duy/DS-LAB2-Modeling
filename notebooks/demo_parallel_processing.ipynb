# %% [markdown]
# # Demo: Parallel Data Processing Pipeline
#
# This notebook demonstrates how to use the multi-threaded capability of the processing pipeline to speed up data extraction from LaTeX papers.

# %%
import sys
import os

# Adjust path to import src from the sibling directory '23127011'
# Assuming notebook is running from 'Milestone2_Project/notebooks'
current_dir = os.getcwd()
project_root = os.path.dirname(current_dir) # Go up one level to Milestone2_Project
src_parent_dir = os.path.join(project_root, '23127011')

if src_parent_dir not in sys.path:
    sys.path.append(src_parent_dir)

from src.pipeline import run_processing_pipeline

print(f"Project Root: {project_root}")
print("Successfully imported `run_processing_pipeline`.")
# Out:
# Project Root: d:\Coding\School\Y3-K1\Intro2DS\DS - LAB 2\Milestone2_Project
# Successfully imported `run_processing_pipeline`.

# %%
# Define file paths
# We use the existing 'data_raw' folder and create a new output folder for this demo
DATA_RAW = os.path.join(project_root, 'data_raw_real')
DATA_OUTPUT = os.path.join(project_root, 'data_output_v2')
MAX_WORKERS = os.cpu_count() or 4

print(f"Data Raw Path: {DATA_RAW}")
print(f"Data Output Path: {DATA_OUTPUT}")
print(f"Max Workers: {MAX_WORKERS}")
# Out:
# Data Raw Path: d:\Coding\School\Y3-K1\Intro2DS\DS - LAB 2\Milestone2_Project\data_raw_real
# Data Output Path: d:\Coding\School\Y3-K1\Intro2DS\DS - LAB 2\Milestone2_Project\data_output_v2
# Max Workers: 20

# %%
# Run the pipeline in parallel
print(f"Starting parallel execution... Logs will be written to {os.path.join(DATA_OUTPUT, 'pipeline.log')}")
run_processing_pipeline(DATA_RAW, DATA_OUTPUT, parallel=True, max_workers=MAX_WORKERS)
print("Execution finished.")
# Out:
# Starting parallel execution...
# 🚀 Starting parallel processing with 20 workers...
# 📄 Processing Paper: 2403-00530
# 📄 Processing Paper: 2403-00531
# 📄 Processing Paper: 2403-00532
# 📄 Processing Paper: 2403-00533
# 📄 Processing Paper: 2403-00534
# 📄 Processing Paper: 2403-00535
# 📄 Processing Paper: 2403-00536
# 📄 Processing Paper: 2403-00537
# 📄 Processing Paper: 2403-00538
# 📄 Processing Paper: 2403-00539
# 📄 Processing Paper: 2403-00540
# 📄 Processing Paper: 2403-00541
# 📄 Processing Paper: 2403-00542
# 📄 Processing Paper: 2403-00543
# 📄 Processing Paper: 2403-00544
# 📄 Processing Paper: 2403-00545
#    🔍 Scanning references for 2403-00531v1...
#       Found 49 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00532v1...
#       Found 258 cited keys (Regex engine).
# 📄 Processing Paper: 2403-00546
# 📄 Processing Paper: 2403-00547
#         -> Parsed 258 items from embedded_block
#       Matched 258 references.
#       Found 258 references in 2403-00532v1.
# 📄 Processing Paper: 2403-00548
#    🔍 Scanning references for 2403-00533v1...
#       Found 162 cited keys (Regex engine).
# 📄 Processing Paper: 2403-00549
#    🔍 Scanning references for 2403-00538v1...
#       Found 34 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00536v1...
#       Found 32 cited keys (Regex engine).
#    ✅ Finished processing 2403-00542
# 📄 Processing Paper: 2403-00550
#    🔍 Scanning references for 2403-00539v1...
#       Found 70 cited keys (Regex engine).
#         -> Parsed 34 items from main.bbl
#         -> Parsed 32 items from arxiv-dynamic-knapsack.bbl
#       Matched 34 references.
#       Found 34 references in 2403-00538v1.
#    🔍 Scanning references for 2403-00540v1...
#       Found 32 cited keys (Regex engine).
#       Matched 32 references.
#       Found 32 references in 2403-00536v1.
#    🔍 Scanning references for 2403-00534v1...
#       Found 42 cited keys (Regex engine).
#    🔍 Scanning references for 2403.00544v1...
#       Found 114 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00545v1...
#       Found 33 cited keys (Regex engine).
#         -> Parsed 114 items from embedded_block
#       Matched 114 references.
#       Found 114 references in 2403.00544v1.
#         -> Parsed 32 items from EpsilonGreedy.bbl
#       Matched 32 references.
#       Found 32 references in 2403-00540v1.
#         -> Parsed 1 items from main.bbl   🔍 Scanning references for 2403-00541v1...
#       Found 37 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00535v1...
#       Found 78 cited keys (Regex engine).
#
#       Matched 49 references.
#       Found 49 references in 2403-00531v1.
#         -> Parsed 42 items from 1rdm.bbl
#       Matched 42 references.
#       Found 42 references in 2403-00534v1.
#    🔍 Scanning references for 2403-00548v1...
#       Found 16 cited keys (Regex engine).
#         -> Parsed 37 items from MAIN.bbl
#    🔍 Scanning references for 2403-00532v2...
#       Found 264 cited keys (Regex engine).
#       Matched 37 references.
#       Found 37 references in 2403-00541v1.
#         -> Parsed 272 items from embedded_block
#       Matched 264 references.
#       Found 264 references in 2403-00532v2.
#    🔍 Scanning references for 2403-00531v2...
#       Found 62 cited keys (Regex engine).
#         -> Parsed 67 items from apssamp.bbl
#         -> Parsed 78 items from Winnberg-etal-jpg.bbl
#         -> Parsed 16 items from main.bbl
#    🔍 Scanning references for 2403.00544v2...
#       Found 120 cited keys (Regex engine).
#         -> Parsed 120 items from embedded_block
#       Matched 120 references.
#       Found 120 references in 2403.00544v2.
#    🔍 Scanning references for 2403-00543v1...
#       Found 83 cited keys (Regex engine).
#       Matched 78 references.
#       Found 78 references in 2403-00535v1.
#       Matched 162 references.
#       Found 162 references in 2403-00533v1.
#       Matched 33 references.
#       Found 33 references in 2403-00545v1.
#       Matched 62 references.
#       Found 62 references in 2403-00531v2.
#         -> Parsed 83 items from main.bbl
#    🔍 Scanning references for 2403-00538v2...
#       Found 44 cited keys (Regex engine).
# Entry type control not standard. Not considered.
#    🔍 Scanning references for 2403-00547v1...
#       Found 41 cited keys (Regex engine).
#       Matched 16 references.
#       Found 16 references in 2403-00548v1.
#    🔍 Scanning references for 2403-00546v1...
#       Found 36 cited keys (Regex engine).
#    ✅ Finished processing 2403-00544
# 📄 Processing Paper: 2403-00551
#         -> Parsed 44 items from main_new.bbl
#    ✅ Finished processing 2403-00534
# 📄 Processing Paper: 2403-00552
#         -> Parsed 49 items from 48871corr.bbl
#       Matched 41 references.
#       Found 41 references in 2403-00547v1.
#         -> Parsed 36 items from templateArxiv.bbl
#    ✅ Finished processing 2403-00541
# 📄 Processing Paper: 2403-00553
#    🔍 Scanning references for 2403.00545v2...
#       Found 51 cited keys (Regex engine).
#    ✅ Finished processing 2403-00536
# 📄 Processing Paper: 2403-00554
#    🔍 Scanning references for 2403-00533v2...
#       Found 163 cited keys (Regex engine).
#         -> Parsed 51 items from embedded_block
#       Matched 51 references.
#       Found 51 references in 2403.00545v2.
# Overwriting existing string for key: pami.
# Overwriting existing string for key: ijcv.
# Overwriting existing string for key: cvpr.
#    🔍 Scanning references for 2403-00530v1...
#       Found 65 cited keys (Regex engine).
#    ✅ Finished processing 2403-00531
# 📄 Processing Paper: 2403-00555
#    🔍 Scanning references for 2403.00552v1...
#       Found 35 cited keys (Regex engine).
#    ✅ Finished processing 2403-00532
# 📄 Processing Paper: 2403-00556
#         -> Parsed 35 items from embedded_block
#       Matched 35 references.
#       Found 35 references in 2403.00552v1.
#       Matched 36 references.
#       Found 36 references in 2403-00546v1.
#    🔍 Scanning references for 2403-00540v2...
#       Found 55 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00549v1...
#       Found 31 cited keys (Regex engine).
#    🔍 Scanning references for 2403.00555v1...
#       Found 61 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00548v2...
#       Found 18 cited keys (Regex engine).
# Overwriting existing string for key: iccv.
# Entry type control not standard. Not considered.
# Overwriting existing string for key: eccv.
#         -> Parsed 61 items from embedded_block
#       Matched 61 references.
#       Found 61 references in 2403.00555v1.
#         -> Parsed 55 items from GreedyBO.bbl
#       Matched 55 references.
#       Found 55 references in 2403-00540v2.
#         -> Parsed 18 items from main.bbl
#       Matched 163 references.
#       Found 163 references in 2403-00533v2.
#       Matched 65 references.
#       Found 65 references in 2403-00530v1.
#    ✅ Finished processing 2403-00546
# 📄 Processing Paper: 2403-00557
#       Matched 31 references.
#       Found 31 references in 2403-00549v1.
#    ✅ Finished processing 2403-00547
# 📄 Processing Paper: 2403-00558
#       Matched 18 references.
#       Found 18 references in 2403-00548v2.
#    ✅ Finished processing 2403-00555
# 📄 Processing Paper: 2403-00559
#    ✅ Finished processing 2403-00535
# 📄 Processing Paper: 2403-00560
#    🔍 Scanning references for 2403.00552v2...
#       Found 37 cited keys (Regex engine).
#       Matched 44 references.
#       Found 44 references in 2403-00538v2.
# Entry type standard not standard. Not considered.
# Overwriting existing string for key: nips.
# Entry type standard not standard. Not considered.
# Overwriting existing string for key: icpr.
# Entry type standard not standard. Not considered.
#    🔍 Scanning references for 2403-00556v1...
#       Found 26 cited keys (Regex engine).
#         -> Parsed 37 items from embedded_block
#       Matched 37 references.
#       Found 37 references in 2403.00552v2.
#    ✅ Finished processing 2403-00545
# 📄 Processing Paper: 2403-00561
#    ✅ Finished processing 2403-00533
# 📄 Processing Paper: 2403-00562
#    🔍 Scanning references for 2403-00559v1...
#       Found 42 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00540v3...
#       Found 61 cited keys (Regex engine).
#         -> Parsed 42 items from embedded_block
#       Matched 42 references.
#       Found 42 references in 2403-00559v1.
#    🔍 Scanning references for 2403-00537v1...
#       Found 19 cited keys (Regex engine).
#       Matched 25 references.
#       Found 25 references in 2403-00556v1.
# Overwriting existing string for key: bmvc.
# Overwriting existing string for key: tog.
# Overwriting existing string for key: tip.
# Overwriting existing string for key: tvcg.
#         -> Parsed 19 items from Paper.bbl
#    🔍 Scanning references for 2403-00554v1...
#       Found 37 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00557v1...
#       Found 23 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00558v1...
#       Found 20 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00562v1...
#       Found 17 cited keys (Regex engine).
# Overwriting existing string for key: tmm.
# Overwriting existing string for key: acmmm.
# Overwriting existing string for key: icme.
#         -> Parsed 23 items from main.bbl
#         -> Parsed 61 items from GreedyBO.bbl
#       Matched 61 references.
#       Found 61 references in 2403-00540v3.
#    🔍 Scanning references for 2403-00561v1...
#       Found 31 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00560v1...
#       Found 17 cited keys (Regex engine).
#    ✅ Finished processing 2403-00548
# 📄 Processing Paper: 2403-00563
#       Matched 23 references.
#       Found 23 references in 2403-00557v1.
#    ✅ Finished processing 2403-00538
# 📄 Processing Paper: 2403-00564
#       Matched 19 references.
#       Found 19 references in 2403-00537v1.
#         -> Parsed 31 items from main.bbl
#    🔍 Scanning references for 2403-00559v2...
#       Found 45 cited keys (Regex engine).
#         -> Parsed 25 items from main.bbl
# Overwriting existing string for key: icassp.
# Overwriting existing string for key: icip.
# Overwriting existing string for key: accv.
# Overwriting existing string for key: iclr.
#         -> Parsed 17 items from main.bbl
#         -> Parsed 45 items from embedded_block
#       Matched 45 references.
#       Found 45 references in 2403-00559v2.
#    ✅ Finished processing 2403-00552
# 📄 Processing Paper: 2403-00565
#    🔍 Scanning references for 2403-00556v2...
#       Found 26 cited keys (Regex engine).
#       Matched 31 references.
#       Found 31 references in 2403-00561v1.
#         -> Parsed 37 items from Collaborative-collision-avoidance.bbl
#       Matched 17 references.
#       Found 17 references in 2403-00560v1.
#       Matched 37 references.
#       Found 37 references in 2403-00554v1.
#       Matched 20 references.
#       Found 20 references in 2403-00558v1.
#       Matched 17 references.
#       Found 17 references in 2403-00562v1.
# Overwriting existing string for key: ijcai.
# Overwriting existing string for key: pr.
# Overwriting existing string for key: aaai.
#    ✅ Finished processing 2403-00557
# 📄 Processing Paper: 2403-00566
#    🔍 Scanning references for 2403-00550v1...
#       Found 8 cited keys (Regex engine).
#       Matched 25 references.
#       Found 25 references in 2403-00556v2.
#    ✅ Finished processing 2403-00559
# 📄 Processing Paper: 2403-00567
#    ✅ Finished processing 2403-00561
# 📄 Processing Paper: 2403-00568
#    ✅ Finished processing 2403-00540
# 📄 Processing Paper: 2403-00569
#         -> Parsed 2 items from main.bbl
#       Matched 8 references.
#       Found 8 references in 2403-00550v1.
#    🔍 Scanning references for 2403-00549v2...
#       Found 31 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00567v1...
#       Found 37 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00566v1...
#       Found 48 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00562v2...
#       Found 22 cited keys (Regex engine).
# Entry type electronic not standard. Not considered.
# Overwriting existing string for key: cvprw.
#         -> Parsed 48 items from laststraw2024.bbl
#    🔍 Scanning references for 2403-00568v1...
#       Found 15 cited keys (Regex engine).
#         -> Parsed 30 items from main.bbl
#    🔍 Scanning references for 2403-00558v2...
#       Found 20 cited keys (Regex engine).
#       Matched 31 references.
#       Found 31 references in 2403-00549v2.
# Overwriting existing string for key: pami.
# Overwriting existing string for key: csvt.
# Overwriting existing string for key: ijcv.
# Entry type standard not standard. Not considered.
# Overwriting existing string for key: cvpr.
# Entry type standard not standard. Not considered.
#    🔍 Scanning references for 2403-00569v1...
#       Found 13 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00551v1...
#       Found 0 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00537v2...
#       Found 19 cited keys (Regex engine).
#       Matched 48 references.
#       Found 48 references in 2403-00566v1.
#         -> Parsed 28 items from embedded_block
#       ⚠️ No citations found, returning all parsed references.
#       Matched 28 references.
#       Found 28 references in 2403-00551v1.
#         -> Parsed 13 items from RIS_MU2023.bbl
#         -> Parsed 19 items from Paper.bbl
#    🔍 Scanning references for 2403-00560v2...
#       Found 24 cited keys (Regex engine).
#       Matched 15 references.
#       Found 15 references in 2403-00568v1.
#       Matched 22 references.
#       Found 22 references in 2403-00562v2.
#         -> Parsed 24 items from embedded_block
#       Matched 24 references.
#       Found 24 references in 2403-00560v2.
#       Matched 83 references.
#       Found 83 references in 2403-00543v1.
#    ✅ Finished processing 2403-00550
# 📄 Processing Paper: 2403-00570
#       Matched 13 references.
#       Found 13 references in 2403-00569v1.
# Overwriting existing string for key: iccv.
# Entry type standard not standard. Not considered.
# Overwriting existing string for key: eccv.
# Entry type standard not standard. Not considered.
# Overwriting existing string for key: nips.
#    🔍 Scanning references for 2403-00530v2...
#       Found 92 cited keys (Regex engine).
#       Matched 20 references.
#       Found 20 references in 2403-00558v2.
#       Matched 19 references.
#       Found 19 references in 2403-00537v2.
#         -> Parsed 92 items from main_rerev2025.bbl
#    ✅ Finished processing 2403-00566
# 📄 Processing Paper: 2403-00571
#    ✅ Finished processing 2403-00562
# 📄 Processing Paper: 2403-00572
#    ✅ Finished processing 2403-00568
# 📄 Processing Paper: 2403-00573
#    🔍 Scanning references for 2403-00554v2...
#       Found 36 cited keys (Regex engine).
#    ✅ Finished processing 2403-00560
# 📄 Processing Paper: 2403-00574
#    🔍 Scanning references for 2403-00556v3...
#       Found 26 cited keys (Regex engine).
#    ✅ Finished processing 2403-00569
# 📄 Processing Paper: 2403-00575
#         -> Parsed 36 items from Collaborative_collision_avoidance.bbl
#       Matched 36 references.
#       Found 36 references in 2403-00554v2.
#    ✅ Finished processing 2403-00558
# 📄 Processing Paper: 2403-00576
#    🔍 Scanning references for 2403-00572v1...
#       Found 59 cited keys (Regex engine).
#       Matched 25 references.
#       Found 25 references in 2403-00556v3.
# Overwriting existing string for key: icpr.
# Entry type thesis not standard. Not considered.
# Overwriting existing string for key: bmvc.
# Overwriting existing string for key: tog.
#    ✅ Finished processing 2403-00537      Matched 92 references.
#       Found 92 references in 2403-00530v2.
#
# 📄 Processing Paper: 2403-00577
#    🔍 Scanning references for 2403-00573v1...
#       Found 18 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00571v1...
#       Found 72 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00575v1...
#       Found 47 cited keys (Regex engine).
#         -> Parsed 69 items from main.bbl
#         -> Parsed 18 items from main.bbl
#         -> Parsed 47 items from Equivariant_Spectral_Flow_for_Dirac-type_Operators_vf.bbl
#       Matched 47 references.
#       Found 47 references in 2403-00575v1.
# Overwriting existing string for key: tip.
# Overwriting existing string for key: tvcg.
#         -> Parsed 72 items from sn-article.bbl
#    ✅ Finished processing 2403-00543
# 📄 Processing Paper: 2403-00578
#       Matched 18 references.
#       Found 18 references in 2403-00573v1.
#    ✅ Finished processing 2403-00530
# 📄 Processing Paper: 2403-00579
# Overwriting existing string for key: tmm.
# Overwriting existing string for key: acmmm.
# Overwriting existing string for key: icme.
# Overwriting existing string for key: icassp.
# Overwriting existing string for key: icip.
#    ✅ Finished processing 2403-00551
# 📄 Processing Paper: 2403-00580
#    ✅ Finished processing 2403-00554
# 📄 Processing Paper: 2403-00581
#    🔍 Scanning references for 2403-00576v1...
#       Found 38 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00549v3...
#       Found 31 cited keys (Regex engine).
#         -> Parsed 38 items from main.bbl
#    ✅ Finished processing 2403-00556
# 📄 Processing Paper: 2403-00582
#    ✅ Finished processing 2403-00573
# 📄 Processing Paper: 2403-00583
#       Matched 72 references.
#       Found 72 references in 2403-00571v1.
#    🔍 Scanning references for 2403-00564v1...
#       Found 41 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00565v1...
#       Found 41 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00575v2...
#       Found 48 cited keys (Regex engine).
#       Matched 59 references.
#       Found 59 references in 2403-00572v1.
#         -> Parsed 48 items from Equivariant_Spectral_Flow_for_Dirac-type_Operators_vf.bbl
#       Matched 70 references.
#       Found 70 references in 2403-00539v1.
#       Matched 48 references.
#       Found 48 references in 2403-00575v2.
#    🔍 Scanning references for 2403-00580v1...
#       Found 181 cited keys (Regex engine).
#       Matched 38 references.
#       Found 38 references in 2403-00576v1.
#         -> Parsed 41 items from bare_jrnl.bbl
#       Matched 41 references.
#       Found 41 references in 2403-00565v1.
#    🔍 Scanning references for 2403-00577v1...
#       Found 58 cited keys (Regex engine).
#         -> Parsed 206 items from frontiers.bbl
#       Matched 31 references.
#       Found 31 references in 2403-00549v3.
#         -> Parsed 59 items from arxiv.bbl
#       Matched 58 references.
#       Found 58 references in 2403-00577v1.
#         -> Parsed 41 items from example_paper.bbl
# Overwriting existing string for key: accv.
# Overwriting existing string for key: iclr.
# Overwriting existing string for key: ijcai.
# Overwriting existing string for key: pr.
#    ✅ Finished processing 2403-00571
# 📄 Processing Paper: 2403-00584
#    🔍 Scanning references for 2403.00583v1...
#       Found 12 cited keys (Regex engine).
#         -> Parsed 12 items from embedded_block
#       Matched 12 references.
#       Found 12 references in 2403.00583v1.
#       Matched 41 references.
#       Found 41 references in 2403-00564v1.
#    ✅ Finished processing 2403-00572
# 📄 Processing Paper: 2403-00585
#    ✅ Finished processing 2403-00539
# 📄 Processing Paper: 2403-00586
#    🔍 Scanning references for 2403-00582v1...
#       Found 1 cited keys (Regex engine).
# Overwriting existing string for key: aaai.
# Overwriting existing string for key: cvprw.
# Overwriting existing string for key: amstrans.
#    🔍 Scanning references for 2403-00581v1...   ✅ Finished processing 2403-00576
# 📄 Processing Paper: 2403-00587
#    🔍 Scanning references for 2403-00578v1...
#       Found 11 cited keys (Regex engine).
#
#       Found 67 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00577v2...
#       Found 88 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00575v3...
#       Found 51 cited keys (Regex engine).
#    🔍 Scanning references for 2403.00583v2...
#       Found 12 cited keys (Regex engine).
#         -> Parsed 12 items from embedded_block
#       Matched 12 references.
#       Found 12 references in 2403.00583v2.
#         -> Parsed 30 items from Benchmarking_SINDy_ArXiv.bbl
# Overwriting existing string for key: csvt.
#         -> Parsed 51 items from Hochs-Yanes_revision.bbl
#       Matched 51 references.
#       Found 51 references in 2403-00575v3.
#    ✅ Finished processing 2403-00549
# 📄 Processing Paper: 2403-00588
#         -> Parsed 88 items from hagedorn_svl_ha_v11.bbl
#       Matched 88 references.
#       Found 88 references in 2403-00577v2.
#    🔍 Scanning references for 2403-00584v1...
#       Found 46 cited keys (Regex engine).
# Overwriting existing string for key: bullams.
# Overwriting existing string for key: procams.
# Overwriting existing string for key: transams.
# Overwriting existing string for key: cacm.
#    🔍 Scanning references for 2403-00588v1...
#       Found 10 cited keys (Regex engine).
#         -> Parsed 12 items from embedded_block
#       Matched 10 references.
#       Found 10 references in 2403-00588v1.
#    🔍 Scanning references for 2403-00586v1...
#       Found 17 cited keys (Regex engine).
#       Matched 10 references.
#       Found 10 references in 2403-00578v1.
#       Matched 181 references.
#       Found 181 references in 2403-00580v1.
#         -> Parsed 17 items from acl_latex.bbl
#       Matched 37 references.
#       Found 37 references in 2403-00567v1.
#         -> Parsed 67 items from main.bbl
#       Matched 67 references.
#       Found 67 references in 2403-00581v1.
#    🔍 Scanning references for 2403.00583v3...
#       Found 12 cited keys (Regex engine).
#       Matched 46 references.
#       Found 46 references in 2403-00584v1.
#    🔍 Scanning references for 2403-00585v1...
#       Found 21 cited keys (Regex engine).
# Overwriting existing string for key: acmmathsoft.
# Overwriting existing string for key: signum.
# Overwriting existing string for key: amerstatassoc.
# Overwriting existing string for key: applmathcomp.
#    ✅ Finished processing 2403-00565
# 📄 Processing Paper: 2403-00589
#         -> Parsed 12 items from embedded_block
#       Matched 12 references.
#       Found 12 references in 2403.00583v3.
#         -> Parsed 20 items from references_d2d.bbl
#    🔍 Scanning references for 2403-00587v1...
#       Found 27 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00588v2...
#       Found 10 cited keys (Regex engine).
#         -> Parsed 12 items from embedded_block
#       Matched 10 references.
#       Found 10 references in 2403-00588v2.
#    🔍 Scanning references for 2403-00553v1...
#       Found 44 cited keys (Regex engine).
#         -> Parsed 27 items from acl_latex.bbl
#    ✅ Finished processing 2403-00578
# 📄 Processing Paper: 2403-00590
#       ⛔ SKIPPING large file: anthology.bib
#    🔍 Scanning references for 2403-00577v3...
#       Found 89 cited keys (Regex engine).
#    ✅ Finished processing 2403-00580
# 📄 Processing Paper: 2403-00591
# Overwriting existing string for key: amermathmonthly.
# Entry type online not standard. Not considered.
# Overwriting existing string for key: britstatpsych.
#       Matched 21 references.
#       Found 21 references in 2403-00585v1.
#       Matched 17 references.
#       Found 17 references in 2403-00586v1.
#    ✅ Finished processing 2403-00584
# 📄 Processing Paper: 2403-00592
#    ✅ Finished processing 2403-00583
# 📄 Processing Paper: 2403-00593
#         -> Parsed 89 items from hagedorn_svl_ha_v22.bbl
#       Matched 89 references.
#       Found 89 references in 2403-00577v3.
#       Matched 27 references.
#       Found 27 references in 2403-00587v1.
#    🔍 Scanning references for 2403-00589v1...
#       Found 23 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00581v2...
#       Found 67 cited keys (Regex engine).
# Overwriting existing string for key: canmathbull.
# Overwriting existing string for key: compapplmath.
# Overwriting existing string for key: compphys.
# Overwriting existing string for key: compstruct.
# Overwriting existing string for key: compjour.
# Overwriting existing string for key: compsyssci.
# Overwriting existing string for key: contempmath.
#    🔍 Scanning references for 2403-00563v1...
#       Found 24 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00567v2...
#       Found 37 cited keys (Regex engine).
#    ✅ Finished processing 2403-00586
# 📄 Processing Paper: 2403-00594
#         -> Parsed 1 items from main.bbl
#       Matched 44 references.
#       Found 44 references in 2403-00553v1.
#    ✅ Finished processing 2403-00588
# 📄 Processing Paper: 2403-00595
#    🔍 Scanning references for 2403-00593v1...
#       Found 85 cited keys (Regex engine).
#         -> Parsed 24 items from main.bbl
#       Matched 23 references.
#       Found 23 references in 2403-00589v1.
#    🔍 Scanning references for 2403-00591v1...
#       Found 43 cited keys (Regex engine).
#         -> Parsed 43 items from eccv2022submission.bbl
#         -> Parsed 67 items from main.bbl
#       Matched 67 references.
#       Found 67 references in 2403-00581v2.
#    ✅ Finished processing 2403-00577
# 📄 Processing Paper: 2403-00596
# Overwriting existing string for key: pami.
# Overwriting existing string for key: giornalemath.
#       Matched 43 references.
#       Found 43 references in 2403-00591v1.
#    ✅ Finished processing 2403-00591
# 📄 Processing Paper: 2403-00597
#    🔍 Scanning references for 2403-00597v1...
#       Found 74 cited keys (Regex engine).
#         -> Parsed 73 items from main.bbl
#    ✅ Finished processing 2403-00575
# 📄 Processing Paper: 2403-00598
# Overwriting existing string for key: ijcv.
# Overwriting existing string for key: ieeetranscomp.
# Overwriting existing string for key: ieeetransac.
# Overwriting existing string for key: cvpr.
# Overwriting existing string for key: procieee.
#    ✅ Finished processing 2403-00587      Matched 24 references.
#       Found 24 references in 2403-00563v1.
#
# 📄 Processing Paper: 2403-00599
#       Matched 73 references.
#       Found 73 references in 2403-00597v1.
#    🔍 Scanning references for 2403-00597v2...
#       Found 73 cited keys (Regex engine).
#         -> Parsed 73 items from main.bbl
#    ✅ Finished processing 2403-00585
# 📄 Processing Paper: 2403-00600
#    🔍 Scanning references for 2403-00595v1...
#       Found 12 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00589v2...
#       Found 37 cited keys (Regex engine).
# Overwriting existing string for key: iccv.
# Overwriting existing string for key: eccv.
# Overwriting existing string for key: ieeetransaeroelec.
# Overwriting existing string for key: nips.
# Overwriting existing string for key: imanumerana.
# Overwriting existing string for key: icpr.
# Overwriting existing string for key: infproclet.
# Overwriting existing string for key: instmathapp.
#         -> Parsed 12 items from embedded_block
#       Matched 12 references.
#       Found 12 references in 2403-00595v1.
#       Matched 85 references.
#       Found 85 references in 2403-00593v1.
#    ✅ Finished processing 2403-00581
# 📄 Processing Paper: 2403-00601
#    🔍 Scanning references for 2403-00598v1...
#       Found 20 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00600v1...
#       Found 73 cited keys (Regex engine).
#       Matched 73 references.
#       Found 73 references in 2403-00597v2.
#    🔍 Scanning references for 2403-00599v1...
#       Found 0 cited keys (Regex engine).
#         -> Parsed 73 items from embedded_block
#       Matched 73 references.
#       Found 73 references in 2403-00600v1.
#         -> Parsed 21 items from embedded_block
#       ⚠️ No citations found, returning all parsed references.
#       Matched 21 references.
#       Found 21 references in 2403-00599v1.
#    🔍 Scanning references for 2403-00593v2...
#       Found 86 cited keys (Regex engine).
# Overwriting existing string for key: bmvc.
# Overwriting existing string for key: intcontrol.
# Overwriting existing string for key: tog.
# Overwriting existing string for key: intnumereng.
# Overwriting existing string for key: tip.
#    ✅ Finished processing 2403-00595   ✅ Finished processing 2403-00597
# 📄 Processing Paper: 2403-00602
#
# 📄 Processing Paper: 2403-00603
#       Matched 37 references.
#       Found 37 references in 2403-00589v2.
#    🔍 Scanning references for 2403-00596v1...
#       Found 57 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00600v2...
#       Found 31 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00601v1...
#       Found 43 cited keys (Regex engine).
#    ✅ Finished processing 2403-00599
# 📄 Processing Paper: 2403-00604
#    🔍 Scanning references for 2403-00592v1...
#       Found 58 cited keys (Regex engine).
#         -> Parsed 43 items from main.bbl
# Overwriting existing string for key: intsuper.
# Entry type thesis not standard. Not considered.
# Overwriting existing string for key: tvcg.
#         -> Parsed 58 items from main.bbl
#    🔍 Scanning references for 2403-00590v1...
#       Found 44 cited keys (Regex engine).
#         -> Parsed 50 items from refs.bbl
#         -> Parsed 44 items from Hercules_arxiv.bbl
#       Matched 86 references.
#       Found 86 references in 2403-00593v2.
#       Matched 20 references.
#       Found 20 references in 2403-00598v1.
# Overwriting existing string for key: jresnatburstand.
# Overwriting existing string for key: pami.
# Overwriting existing string for key: tmm.
# Overwriting existing string for key: linalgapp.
# Overwriting existing string for key: ijcv.
#    ✅ Finished processing 2403-00589
# 📄 Processing Paper: 2403-00605
#       Matched 31 references.
#       Found 31 references in 2403-00600v2.
#         -> Parsed 7 items from refs_SM.bbl
#    🔍 Scanning references for 2403-00603v1...
#       Found 18 cited keys (Regex engine).
#       Matched 44 references.
#       Found 44 references in 2403-00590v1.
#    🔍 Scanning references for 2403-00602v1...
#       Found 55 cited keys (Regex engine).
#         -> Parsed 55 items from arXiv.bbl
#       Matched 57 references.
#       Found 57 references in 2403-00596v1.
#         -> Parsed 18 items from TGF.bbl
#    ✅ Finished processing 2403-00593
# 📄 Processing Paper: 2403-00606
#    ✅ Finished processing 2403-00598
# 📄 Processing Paper: 2403-00607
# Overwriting existing string for key: acmmm.
# Overwriting existing string for key: mathanaappl.
# Overwriting existing string for key: cvpr.
# Overwriting existing string for key: icme.
# Entry type dataset not standard. Not considered.
# Overwriting existing string for key: mathannalen.
#       Matched 43 references.
#       Found 43 references in 2403-00601v1.
#       Matched 18 references.
#       Found 18 references in 2403-00603v1.
#    🔍 Scanning references for 2403-00605v1...
#       Found 35 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00596v2...
#       Found 63 cited keys (Regex engine).
#         -> Parsed 35 items from 2021_TVT.bbl
#    🔍 Scanning references for 2403-00590v2...
#       Found 30 cited keys (Regex engine).
#         -> Parsed 63 items from main.bbl
#       Matched 55 references.
#       Found 55 references in 2403-00602v1.
# Overwriting existing string for key: iccv.
# Overwriting existing string for key: icassp.
# Overwriting existing string for key: mathphys.
# Overwriting existing string for key: eccv.
#         -> Parsed 28 items from Hercules_arxiv_v2.bbl
#    ✅ Finished processing 2403-00601
# 📄 Processing Paper: 2403-00608
#    🔍 Scanning references for 2403-00606v1...
#       Found 18 cited keys (Regex engine).
#         -> Parsed 18 items from main_ICASSP.bbl
#       Matched 35 references.
#       Found 35 references in 2403-00605v1.
#    🔍 Scanning references for 2403-00604v1...
#       Found 23 cited keys (Regex engine).
# Overwriting existing string for key: icip.
# Overwriting existing string for key: mathcomp.
# Overwriting existing string for key: nips.
# Overwriting existing string for key: accv.
# Overwriting existing string for key: mathscand.
# Overwriting existing string for key: icpr.
#    ✅ Finished processing 2403-00600
# 📄 Processing Paper: 2403-00609
#    🔍 Scanning references for 2403-00564v2...
#       Found 40 cited keys (Regex engine).
#       Matched 63 references.
#       Found 63 references in 2403-00596v2.
#       Matched 18 references.
#       Found 18 references in 2403-00606v1.
# Overwriting existing string for key: iclr.
# Overwriting existing string for key: tablesaidscomp.
# Overwriting existing string for key: bmvc.
# Overwriting existing string for key: ijcai.
# Overwriting existing string for key: numermath.
# Entry type dataset not standard. Not considered.
# Overwriting existing string for key: tog.
# Overwriting existing string for key: pr.
#       Matched 23 references.   🔍 Scanning references for 2403-00602v2...
#       Found 58 cited keys (Regex engine).
#
#       Found 23 references in 2403-00604v1.
#       Matched 28 references.
#       Found 28 references in 2403-00590v2.
#         -> Parsed 58 items from arXiv.bbl
#    🔍 Scanning references for 2403.00609v1...
#       Found 41 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00603v2...
#       Found 18 cited keys (Regex engine).
#         -> Parsed 44 items from embedded_block
#       Matched 41 references.
#       Found 41 references in 2403.00609v1.
#       Matched 39 references.
#       Found 39 references in 2403-00564v2.
#    ✅ Finished processing 2403-00606
# 📄 Processing Paper: 2403-00610
#    🔍 Scanning references for 2403-00608v1...
#       Found 97 cited keys (Regex engine).
#    ✅ Finished processing 2403-00605
# 📄 Processing Paper: 2403-00611
#         -> Parsed 18 items from TGF.bbl
#    ✅ Finished processing 2403-00610
# 📄 Processing Paper: 2403-00612
#    ✅ Finished processing 2403-00590
# 📄 Processing Paper: 2403-00613
#    ✅ Finished processing 2403-00609
# 📄 Processing Paper: 2403-00614
#       Matched 58 references.
#       Found 58 references in 2403-00602v2.
#         -> Parsed 113 items from main_clear.bbl
# Overwriting existing string for key: pacificmath.
# Overwriting existing string for key: tip.
# Overwriting existing string for key: aaai.
# Overwriting existing string for key: pardistcomp.
# Overwriting existing string for key: tvcg.
#       Matched 18 references.
#       Found 18 references in 2403-00603v2.
#    ✅ Finished processing 2403-00596
# 📄 Processing Paper: 2403-00615
#    🔍 Scanning references for 2403-00614v1...
#       Found 47 cited keys (Regex engine).
#         -> Parsed 47 items from tdas_for_btcsvfinal.bbl
#       Matched 47 references.
#       Found 47 references in 2403-00614v1.
#    🔍 Scanning references for 2403-00613v1...
#       Found 44 cited keys (Regex engine).
#    ✅ Finished processing 2403-00602
# 📄 Processing Paper: 2403-00616
#    🔍 Scanning references for 2403-00612v1...
#       Found 45 cited keys (Regex engine).
#    ✅ Finished processing 2403-00603
# 📄 Processing Paper: 2403-00617
#         -> Parsed 44 items from TRO_2022Crack_v14.bbl
#       Matched 44 references.
#       Found 44 references in 2403-00613v1.
# Overwriting existing string for key: cvprw.
# Overwriting existing string for key: parcomputing.
# Overwriting existing string for key: tmm.
#         -> Parsed 45 items from main.bbl
#    🔍 Scanning references for 2403-00611v1...
#       Found 10 cited keys (Regex engine).
#         -> Parsed 10 items from embedded_block
#       Matched 10 references.
#       Found 10 references in 2403-00611v1.
#    🔍 Scanning references for 2403-00615v1...
#       Found 61 cited keys (Regex engine).
#       Matched 45 references.
#       Found 45 references in 2403-00612v1.
#    🔍 Scanning references for 2403-00579v1...
#       Found 51 cited keys (Regex engine).
#       Matched 97 references.
#       Found 97 references in 2403-00608v1.
#         -> Parsed 51 items from paper.bbl
#         -> Parsed 61 items from main.bbl
#       Matched 61 references.
#       Found 61 references in 2403-00615v1.
#    🔍 Scanning references for 2403-00614v2...
#       Found 48 cited keys (Regex engine).
#    ✅ Finished processing 2403-00564
# 📄 Processing Paper: 2403-00618
#    🔍 Scanning references for 2403-00613v2...
#       Found 44 cited keys (Regex engine).
# Overwriting existing string for key: csvt.
# Overwriting existing string for key: philmag.
# Overwriting existing string for key: acmmm.
# Entry type webpage not standard. Not considered.
#         -> Parsed 48 items from tdas_for_btcs_updated.bbl
#       Matched 48 references.
#       Found 48 references in 2403-00614v2.
#    🔍 Scanning references for 2403-00611v2...
#       Found 16 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00616v1...
#       Found 79 cited keys (Regex engine).
#    🔍 Scanning references for 2403-00617v1...
#       Found 0 cited keys (Regex engine).
#         -> Parsed 79 items from main.bbl
#    🔍 Scanning references for 2403-00570v1...
#       Found 97 cited keys (Regex engine).
#       ⚠️ No citations found, returning all parsed references.
#       Matched 0 references.
#       Found 0 references in 2403-00617v1.
#         -> Parsed 16 items from embedded_block
#       Matched 16 references.
#       Found 16 references in 2403-00611v2.
#         -> Parsed 97 items from main.bbl
#         -> Parsed 1 items from main_si.bbl
#    ✅ Finished processing 2403-00615
# 📄 Processing Paper: 2403-00619
#         -> Parsed 44 items from TRO_Crack_Final_copyright.bbl
#       Matched 44 references.
#       Found 44 references in 2403-00613v2.
#       Matched 97 references.
#       Found 97 references in 2403-00570v1.
# Overwriting existing string for key: procnas.

# %%
# Verify outputs
if os.path.exists(DATA_OUTPUT):
    output_folders = os.listdir(DATA_OUTPUT)
    print(f"Total papers processed: {len(output_folders)}")
    if output_folders:
        print(f"Sample output: {output_folders[:5]}")
        
        # Check contents of one folder
        sample_paper = output_folders[0]
        sample_path = os.path.join(DATA_OUTPUT, sample_paper)
        print(f"\nContents of {sample_paper}:")
        for f in os.listdir(sample_path):
            print(f" - {f}")
else:
    print("Output directory was not created.")
